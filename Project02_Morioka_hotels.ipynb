# %%
# !pip install requests
# Out:
# ...
#
# [notice] A new release of pip is available: 23.0.1 -> 23.1.2
# [notice] To update, run: pip install --upgrade pip

# %%
import requests
import pandas as pd

# %%
REQUEST_URL = 'https://app.rakuten.co.jp/services/api/Travel/SimpleHotelSearch/20170426'
APP_ID = '1083760392345829822'

# %%
params = {
    'format': 'json',
    'largeClassCode': 'japan',
    'middleClassCode': 'iwate',
    'smallClassCode': 'morioka',
    'applicationId': APP_ID
}

# %%
response = requests.get(REQUEST_URL, params)

# %%
response
# Out:
# <Response [200]>

# %%
result = response.json()

# %%
result
# Out:
# {'pagingInfo': {'recordCount': 55,
#   'pageCount': 2,
#   'page': 1,
#   'first': 1,
#   'last': 30},
#  'hotels': [{'hotel': [{'hotelBasicInfo': {'hotelNo': 183248,
#       'hotelName': 'ダイワロイネットホテル盛岡駅前',
#       'hotelInformationUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/dQ4dX/?f_no=183248',
#       'planListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/cHNRi/?f_no=183248&f_flg=PLAN',
#       'dpPlanListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/TDZXm/?noTomariHotel=183248',
#       'reviewUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/RmfmX/?f_hotel_no=183248',
#       'hotelKanaName': 'だいわろいねっとほてるもりおかえきまえ',
#       'hotelSpecial': 'JR盛岡駅より徒歩3分の好立地。開運橋の袂に新たなビジネス・観光の拠点が誕生。',
#       'hotelMinCharge': 3900,
#       'latitude': 142916.27,
#       'longitude': 508113.04,
#       'postalCode': '020-0034',
#       'address1': '岩手県',
#       'address2': '盛岡市盛岡駅前通7-15',
#       'telephoneNo': '019-621-8555',
#       'faxNo': '019-621-8556',
# ...

# %%
hotel_info = result['hotels'][0]['hotel'][0]['hotelBasicInfo']
type(hotel_info)
# Out:
# dict

# %%
hotel_info
# Out:
# {'hotelNo': 183248,
#  'hotelName': 'ダイワロイネットホテル盛岡駅前',
#  'hotelInformationUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/dQ4dX/?f_no=183248',
#  'planListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/cHNRi/?f_no=183248&f_flg=PLAN',
#  'dpPlanListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/TDZXm/?noTomariHotel=183248',
#  'reviewUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/RmfmX/?f_hotel_no=183248',
#  'hotelKanaName': 'だいわろいねっとほてるもりおかえきまえ',
#  'hotelSpecial': 'JR盛岡駅より徒歩3分の好立地。開運橋の袂に新たなビジネス・観光の拠点が誕生。',
#  'hotelMinCharge': 3900,
#  'latitude': 142916.27,
#  'longitude': 508113.04,
#  'postalCode': '020-0034',
#  'address1': '岩手県',
#  'address2': '盛岡市盛岡駅前通7-15',
#  'telephoneNo': '019-621-8555',
#  'faxNo': '019-621-8556',
#  'access': 'JR盛岡駅より徒歩約3分。東口より地下道A1出口を出て開運橋方面に約100ｍ。',
#  'parkingInformation': '機械式立体駐車場60台。先着順。1泊1,100円（税込）でご用意。満車時は提携駐車場をご案内します。',
#  'nearestStation': '盛岡',
# ...

# %%
pd.DataFrame(hotel_info, index=[0])
# Out:
#    hotelNo        hotelName  \
# 0   183248  ダイワロイネットホテル盛岡駅前
#
#                                  hotelInformationUrl  \
# 0  https://img.travel.rakuten.co.jp/image/tr/api/...
#
#                                          planListUrl  \
# 0  https://img.travel.rakuten.co.jp/image/tr/api/...
#
#                                        dpPlanListUrl  \
# 0  https://img.travel.rakuten.co.jp/image/tr/api/...
#
#                                            reviewUrl        hotelKanaName  \
# 0  https://img.travel.rakuten.co.jp/image/tr/api/...  だいわろいねっとほてるもりおかえきまえ
#
#                               hotelSpecial  hotelMinCharge   latitude  ...  \
# 0  JR盛岡駅より徒歩3分の好立地。開運橋の袂に新たなビジネス・観光の拠点が誕生。            3900  142916.27  ...
#
#                                   parkingInformation nearestStation  \
# 0  機械式立体駐車場60台。先着順。1泊1,100円（税込）でご用意。満車時は提携駐車場をご案内...             盛岡
#
#                                        hotelImageUrl  \
# 0  https://img.travel.rakuten.co.jp/share/HOTEL/1...
#
# ...

# %%
pd.DataFrame(hotel_info, index=[0])
# Out:
#    hotelNo        hotelName  \
# 0   183248  ダイワロイネットホテル盛岡駅前
#
#                                  hotelInformationUrl  \
# 0  https://img.travel.rakuten.co.jp/image/tr/api/...
#
#                                          planListUrl  \
# 0  https://img.travel.rakuten.co.jp/image/tr/api/...
#
#                                        dpPlanListUrl  \
# 0  https://img.travel.rakuten.co.jp/image/tr/api/...
#
#                                            reviewUrl        hotelKanaName  \
# 0  https://img.travel.rakuten.co.jp/image/tr/api/...  だいわろいねっとほてるもりおかえきまえ
#
#                               hotelSpecial  hotelMinCharge   latitude  ...  \
# 0  JR盛岡駅より徒歩3分の好立地。開運橋の袂に新たなビジネス・観光の拠点が誕生。            3900  142916.27  ...
#
#                                   parkingInformation nearestStation  \
# 0  機械式立体駐車場60台。先着順。1泊1,100円（税込）でご用意。満車時は提携駐車場をご案内...             盛岡
#
#                                        hotelImageUrl  \
# 0  https://img.travel.rakuten.co.jp/share/HOTEL/1...
#
# ...

# %%
hotel_info = result['hotels'][0]['hotel'][0]['hotelBasicInfo']
pd.DataFrame(hotel_info, index=[0])
# Out:
#    hotelNo        hotelName  \
# 0   183248  ダイワロイネットホテル盛岡駅前
#
#                                  hotelInformationUrl  \
# 0  https://img.travel.rakuten.co.jp/image/tr/api/...
#
#                                          planListUrl  \
# 0  https://img.travel.rakuten.co.jp/image/tr/api/...
#
#                                        dpPlanListUrl  \
# 0  https://img.travel.rakuten.co.jp/image/tr/api/...
#
#                                            reviewUrl        hotelKanaName  \
# 0  https://img.travel.rakuten.co.jp/image/tr/api/...  だいわろいねっとほてるもりおかえきまえ
#
#                               hotelSpecial  hotelMinCharge   latitude  ...  \
# 0  JR盛岡駅より徒歩3分の好立地。開運橋の袂に新たなビジネス・観光の拠点が誕生。            3900  142916.27  ...
#
#                                   parkingInformation nearestStation  \
# 0  機械式立体駐車場60台。先着順。1泊1,100円（税込）でご用意。満車時は提携駐車場をご案内...             盛岡
#
#                                        hotelImageUrl  \
# 0  https://img.travel.rakuten.co.jp/share/HOTEL/1...
#
# ...

# %%
df = pd.DataFrame()

# %%
df = pd.DataFrame()
hotels = result['hotels']

for i, hotel in enumerate(hotels):
    hotel_info = hotel['hotel'][0]['hotelBasicInfo']
    _df = pd.DataFrame(hotel_info, index=[i])
    df = pd.concat([df, _df])

# %%
df.columns
# Out:
# Index(['hotelNo', 'hotelName', 'hotelInformationUrl', 'planListUrl',
#        'dpPlanListUrl', 'reviewUrl', 'hotelKanaName', 'hotelSpecial',
#        'hotelMinCharge', 'latitude', 'longitude', 'postalCode', 'address1',
#        'address2', 'telephoneNo', 'faxNo', 'access', 'parkingInformation',
#        'nearestStation', 'hotelImageUrl', 'hotelThumbnailUrl', 'roomImageUrl',
#        'roomThumbnailUrl', 'hotelMapImageUrl', 'reviewCount', 'reviewAverage',
#        'userReview'],
#       dtype='object')

# %%
df.columns
df.head()
# Out:
#    hotelNo                                  hotelName  \
# 0   183248                            ダイワロイネットホテル盛岡駅前
# 1   172659  天然温泉　さんさの湯　ドーミーイン盛岡（ドーミーイン・御宿野乃　ホテルズグループ）
# 2    80512                              ダイワロイネットホテル盛岡
# 3     5436                                   アートホテル盛岡
# 4   181404                              リッチモンドホテル盛岡駅前
#
#                                  hotelInformationUrl  \
# 0  https://img.travel.rakuten.co.jp/image/tr/api/...
# 1  https://img.travel.rakuten.co.jp/image/tr/api/...
# 2  https://img.travel.rakuten.co.jp/image/tr/api/...
# 3  https://img.travel.rakuten.co.jp/image/tr/api/...
# 4  https://img.travel.rakuten.co.jp/image/tr/api/...
#
#                                          planListUrl  \
# 0  https://img.travel.rakuten.co.jp/image/tr/api/...
# 1  https://img.travel.rakuten.co.jp/image/tr/api/...
# 2  https://img.travel.rakuten.co.jp/image/tr/api/...
# 3  https://img.travel.rakuten.co.jp/image/tr/api/...
# ...

# %%
df.columns
# Out:
# Index(['hotelNo', 'hotelName', 'hotelInformationUrl', 'planListUrl',
#        'dpPlanListUrl', 'reviewUrl', 'hotelKanaName', 'hotelSpecial',
#        'hotelMinCharge', 'latitude', 'longitude', 'postalCode', 'address1',
#        'address2', 'telephoneNo', 'faxNo', 'access', 'parkingInformation',
#        'nearestStation', 'hotelImageUrl', 'hotelThumbnailUrl', 'roomImageUrl',
#        'roomThumbnailUrl', 'hotelMapImageUrl', 'reviewCount', 'reviewAverage',
#        'userReview'],
#       dtype='object')

# %%
df[['latitude', 'longitude']].to_csv('Project02_Morioka_hotelslat&lon.csv', index=False)

# %%
# another way to do it taught by TA 
# df.drop(columns=['hotelNo', 'hotelInfotmationUrl', 'planListUrl', 'dpPlanListUrl', 'reviewUrl', 'hotelKanaName', 'hotelSpecial', 'latitude', 'longitude', ], inplace=True)

# %%
df.hotelMinCharge.mean()
# Out:
# 4500.633333333333

# %%
df.reviewAverage.mean()
# Out:
# 4.1450000000000005
